# %% [markdown]
# # Quanta UI workflow check
#
# Use this notebook with `docs/ui-ux-verification.md`. The final cell raises an intentional error.

# %%
settings = {'project': 'Quanta', 'values': [1, {'nested': 7}]}
counter = 1
settings

# %% [markdown]
# ## Tables and variables
#
# Select a Python environment with pandas for the table checks.

# %%
import pandas as pd
sample = pd.DataFrame({'score': [20, 3, 1, 8], 'group': ['keep', 'drop', 'KEEP', 'keep']})
sample

# %% [markdown]
# ## Stale output
#
# Run the next cell, then change 42 to 43 without running it again.

# %%
answer = 42
answer

# %% [markdown]
# ## Execution progress
#
# Run All, or run this cell and use Jump to Running Cell.

# %%
import time
time.sleep(2)
print('Finished the slow cell')

# %% [markdown]
# ## Error navigation
#
# The next cell intentionally fails. Click its traceback location to return to the source.

# %%
def fail_here():
    raise ValueError('Intentional error for UI verification')

fail_here()
